# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from math import pi

# Create data for all metrics
emotions = ['Anger', 'Calm', 'Disgust', 'Fear', 'Happiness', 'Neutral', 'Sadness', 'Surprise']

# Yadav et al. data (from paper per-class results)
yadav_data = {
    'Accuracy': [82.35, 90.91, 93.55, 68.29, 75.76, 60.00, 81.58, 80.95],
    'Precision': [90.00, 74.00, 85.00, 82.00, 89.00, 60.00, 78.00, 81.00],
    'Recall': [82.00, 91.00, 94.00, 68.00, 76.00, 60.00, 82.00, 81.00],
    'F1-Score': [86.00, 82.00, 89.00, 75.00, 82.00, 60.00, 79.00, 81.00],
}

# Proposed model data (EmotionCRNN - based on actual results: Overall Accuracy 88%)
proposed_data = {
    'Accuracy': [88.10, 97.73, 96.88, 75.00, 91.18, 80.00, 82.05, 86.67],
    'Precision': [97.00, 86.00, 89.00, 89.00, 76.00, 100.00, 82.00, 93.00],
    'Recall': [88.00, 98.00, 97.00, 75.00, 91.00, 80.00, 82.00, 87.00],
    'F1-Score': [93.00, 91.00, 93.00, 81.00, 83.00, 89.00, 82.00, 90.00],
}

# Create DataFrames
df_yadav = pd.DataFrame(yadav_data, index=emotions)
df_proposed = pd.DataFrame(proposed_data, index=emotions)

df_yadav['Model'] = 'Yadav et al.'
df_proposed['Model'] = 'Proposed Model'
df_all = pd.concat([df_yadav, df_proposed])

# %%
print(df_all)
# Out:
#            Accuracy  Precision  Recall  F1-Score           Model
# Anger         82.35       90.0    82.0      86.0    Yadav et al.
# Calm          90.91       74.0    91.0      82.0    Yadav et al.
# Disgust       93.55       85.0    94.0      89.0    Yadav et al.
# Fear          68.29       82.0    68.0      75.0    Yadav et al.
# Happiness     75.76       89.0    76.0      82.0    Yadav et al.
# Neutral       60.00       60.0    60.0      60.0    Yadav et al.
# Sadness       81.58       78.0    82.0      79.0    Yadav et al.
# Surprise      80.95       81.0    81.0      81.0    Yadav et al.
# Anger         88.10       97.0    88.0      93.0  Proposed Model
# Calm          97.73       86.0    98.0      91.0  Proposed Model
# Disgust       96.88       89.0    97.0      93.0  Proposed Model
# Fear          75.00       89.0    75.0      81.0  Proposed Model
# Happiness     91.18       76.0    91.0      83.0  Proposed Model
# Neutral       80.00      100.0    80.0      89.0  Proposed Model
# Sadness       82.05       82.0    82.0      82.0  Proposed Model
# Surprise      86.67       93.0    87.0      90.0  Proposed Model

# %%
# --- Visualization 1: Grouped Bar Charts ---
metrics = ['Accuracy','Precision', 'Recall', 'F1-Score']
for metric in metrics:
    plt.figure(figsize=(10, 6))
    bar_width = 0.35
    x = np.arange(len(emotions))
    plt.bar(x - bar_width/2, df_yadav[metric], width=bar_width, label='Yadav et al.')
    plt.bar(x + bar_width/2, df_proposed[metric], width=bar_width, label='Proposed Model')
    plt.xticks(x, emotions, rotation=45)
    plt.ylabel(f'{metric} (%)')
    plt.title(f'Comparison of {metric} between Yadav et al. and Proposed Model (RAVDESS)')
    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
# --- Visualization 2: Heatmap ---
plt.figure(figsize=(10, 6))
sns.heatmap(df_yadav[metrics].T, annot=True, cmap='YlGnBu', fmt='.1f')
plt.title('Heatmap of Yadav et al. (All Metrics)')
plt.show()

plt.figure(figsize=(10, 6))
sns.heatmap(df_proposed[metrics].T, annot=True, cmap='YlOrRd', fmt='.1f')
plt.title('Heatmap of Proposed Model (All Metrics)')
plt.show()

# %%
# --- Visualization 3: Line Chart ---
for metric in metrics:
    plt.figure(figsize=(10, 6))
    plt.plot(emotions, df_yadav[metric], marker='o', label='Yadav et al.')
    plt.plot(emotions, df_proposed[metric], marker='o', label='Proposed Model')
    plt.title(f'{metric} Trend across Emotions (RAVDESS)')
    plt.xlabel('Emotion')
    plt.ylabel(f'{metric} (%)')
    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.tight_layout()
    plt.show()

# %%
# --- Visualization 4: Radar Chart ---
def make_radar_chart(df1, df2, title):
    categories = list(df1.index)
    N = len(categories)

    angles = [n / float(N) * 2 * pi for n in range(N)]
    angles += angles[:1]

    plt.figure(figsize=(8, 8))
    ax = plt.subplot(111, polar=True)
    plt.xticks(angles[:-1], categories, color='grey', size=8)

    for metric in metrics:
        values1 = df1[metric].tolist()
        values1 += values1[:1]
        values2 = df2[metric].tolist()
        values2 += values2[:1]
        ax.plot(angles, values1, linewidth=1, linestyle='solid', label=f'Yadav - {metric}')
        ax.fill(angles, values1, alpha=0.1)
        ax.plot(angles, values2, linewidth=1, linestyle='solid', label=f'Proposed - {metric}')
        ax.fill(angles, values2, alpha=0.1)

    plt.title(title, size=14, y=1.1)
    plt.legend(loc='upper right', bbox_to_anchor=(1.3, 1.1))
    plt.show()

make_radar_chart(df_yadav, df_proposed, 'Radar Comparison of Metrics per Emotion (RAVDESS)')

# %%
import pandas as pd

# Create data for all metrics
emotions = ['Anger', 'Calm', 'Disgust', 'Fear', 'Happiness', 'Neutral', 'Sadness', 'Surprise']

# Yadav et al. data (from paper per-class results)
yadav_data = {
    'Accuracy': [82.35, 90.91, 93.55, 68.29, 75.76, 60.00, 81.58, 80.95],
    'Precision': [90.00, 74.00, 85.00, 82.00, 89.00, 60.00, 78.00, 81.00],
    'Recall': [82.00, 91.00, 94.00, 68.00, 76.00, 60.00, 82.00, 81.00],
    'F1-Score': [86.00, 82.00, 89.00, 75.00, 82.00, 60.00, 79.00, 81.00],
}

# Proposed model data (EmotionCRNN - based on actual results: Overall Accuracy 88%)
proposed_data = {
    'Accuracy': [88.10, 97.73, 96.88, 75.00, 91.18, 80.00, 82.05, 86.67],
    'Precision': [97.00, 86.00, 89.00, 89.00, 76.00, 100.00, 82.00, 93.00],
    'Recall': [88.00, 98.00, 97.00, 75.00, 91.00, 80.00, 82.00, 87.00],
    'F1-Score': [93.00, 91.00, 93.00, 81.00, 83.00, 89.00, 82.00, 90.00],
}

# Create the comparison table with multi-line headers
data = {
    'Emotion': emotions,
    'Acc_Yadav': yadav_data['Accuracy'],
    'Acc_Prop': proposed_data['Accuracy'],
    'Prec_Yadav': yadav_data['Precision'],
    'Prec_Prop': proposed_data['Precision'],
    'Rec_Yadav': yadav_data['Recall'],
    'Rec_Prop': proposed_data['Recall'],
    'F1_Yadav': yadav_data['F1-Score'],
    'F1_Prop': proposed_data['F1-Score']
}

df = pd.DataFrame(data)

# Print header
print("\n" + "="*120)
print("EMOTION CLASSIFICATION PERFORMANCE COMPARISON")
print("="*120)
print(f"{'':20}  {'Accuracy':20} {'Precision':20} {'Recall':20} {'F1-Score':20}")
print(f"{'Emotion':11} {'Yadav':>9} {'Proposed':>10} {'Yadav':>9} {'Proposed':>10} {'Yadav':>9} {'Proposed':>10} {'Yadav':>9} {'Proposed':>10}")
print("-"*120)

# Print data rows
for i, row in df.iterrows():
    print(f"{row['Emotion']:11} {row['Acc_Yadav']:>9.2f} {row['Acc_Prop']:>10.2f} {row['Prec_Yadav']:>9.2f} {row['Prec_Prop']:>10.2f} {row['Rec_Yadav']:>9.2f} {row['Rec_Prop']:>10.2f} {row['F1_Yadav']:>9.2f} {row['F1_Prop']:>10.2f}")

print("="*120)
# Out:
# ========================================================================================================================
# EMOTION CLASSIFICATION PERFORMANCE COMPARISON
# ========================================================================================================================
#                       Accuracy             Precision            Recall               F1-Score
# Emotion         Yadav   Proposed     Yadav   Proposed     Yadav   Proposed     Yadav   Proposed
# ------------------------------------------------------------------------------------------------------------------------
# Anger           82.35      88.10     90.00      97.00     82.00      88.00     86.00      93.00
# Calm            90.91      97.73     74.00      86.00     91.00      98.00     82.00      91.00
# Disgust         93.55      96.88     85.00      89.00     94.00      97.00     89.00      93.00
# Fear            68.29      75.00     82.00      89.00     68.00      75.00     75.00      81.00
# Happiness       75.76      91.18     89.00      76.00     76.00      91.00     82.00      83.00
# Neutral         60.00      80.00     60.00     100.00     60.00      80.00     60.00      89.00
# Sadness         81.58      82.05     78.00      82.00     82.00      82.00     79.00      82.00
# Surprise        80.95      86.67     81.00      93.00     81.00      87.00     81.00      90.00
# ========================================================================================================================

# %%
from scipy import stats
import numpy as np
import pandas as pd

metrics = ['Accuracy','Precision', 'Recall', 'F1-Score']

alpha = 0.05  # Significance level

# Store results
results = []

print("\n" + "="*100)
print("SHAPIRO-WILK NORMALITY TEST FOR ALL METRICS")
print("="*100)

for metric in metrics:
    print(f"\n{'─'*100}")
    print(f"METRIC: {metric}")
    print(f"{'─'*100}")
    
    yadav = np.array(yadav_data[metric])
    proposed = np.array(proposed_data[metric])
    
    # Perform Shapiro-Wilk test
    stat_y, p_y = stats.shapiro(yadav)
    stat_p, p_p = stats.shapiro(proposed)
    
    # Determine normality
    yadav_normal = p_y > alpha
    proposed_normal = p_p > alpha
    both_normal = yadav_normal and proposed_normal
    
    print(f"\nYadav et al. {metric}:")
    print(f"  Data: {yadav.tolist()}")
    print(f"  Test Statistic: {stat_y:.6f}")
    print(f"  P-value: {p_y:.6f}")
    print(f"  Status: {'✓ NORMAL' if yadav_normal else '✗ NOT NORMAL'} (α = {alpha})")
    
    print(f"\nProposed Model {metric}:")
    print(f"  Data: {proposed.tolist()}")
    print(f"  Test Statistic: {stat_p:.6f}")
    print(f"  P-value: {p_p:.6f}")
    print(f"  Status: {'✓ NORMAL' if proposed_normal else '✗ NOT NORMAL'} (α = {alpha})")
    
    print(f"\nConclusion:")
    if both_normal:
        recommendation = "Paired T-Test"
        print(f"  ✓ Both distributions are NORMAL")
    else:
        recommendation = "Wilcoxon Signed-Rank Test"
        print(f"  ✗ At least one distribution is NOT NORMAL")
    
    print(f"  → Recommended Test: {recommendation}")
    
    # Store results
    results.append({
        'Metric': metric,
        'Yadav_Statistic': stat_y,
        'Yadav_P-Value': p_y,
        'Yadav_Normal': yadav_normal,
        'Proposed_Statistic': stat_p,
        'Proposed_P-Value': p_p,
        'Proposed_Normal': proposed_normal,
        'Both_Normal': both_normal,
        'Recommended_Test': recommendation
    })

# Create summary table
print(f"\n{'='*100}")
print("SUMMARY TABLE")
print(f"{'='*100}\n")

df_results = pd.DataFrame(results)
print(df_results.to_string(index=False))

# Print recommendation summary
print(f"\n{'='*100}")
print("OVERALL RECOMMENDATIONS")
print(f"{'='*100}")

for _, row in df_results.iterrows():
    print(f"\n{row['Metric']}:")
    print(f"  Yadav Status:    {row['Yadav_Normal']} (p = {row['Yadav_P-Value']:.6f})")
    print(f"  Proposed Status: {row['Proposed_Normal']} (p = {row['Proposed_P-Value']:.6f})")
    print(f"  Test to Use:     {row['Recommended_Test']}")

print(f"\n{'='*100}\n")
# Out:
# ====================================================================================================
# SHAPIRO-WILK NORMALITY TEST FOR ALL METRICS
# ====================================================================================================
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# METRIC: Accuracy
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#
# Yadav et al. Accuracy:
#   Data: [82.35, 90.91, 93.55, 68.29, 75.76, 60.0, 81.58, 80.95]
#   Test Statistic: 0.952732
#   P-value: 0.738721
#   Status: ✓ NORMAL (α = 0.05)
#
# Proposed Model Accuracy:
#   Data: [88.1, 97.73, 96.88, 75.0, 91.18, 80.0, 82.05, 86.67]
#   Test Statistic: 0.961554
#   P-value: 0.824764
#   Status: ✓ NORMAL (α = 0.05)
#
# Conclusion:
#   ✓ Both distributions are NORMAL
#   → Recommended Test: Paired T-Test
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# METRIC: Precision
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#
# Yadav et al. Precision:
#   Data: [90.0, 74.0, 85.0, 82.0, 89.0, 60.0, 78.0, 81.0]
#   Test Statistic: 0.898184
#   P-value: 0.278252
#   Status: ✓ NORMAL (α = 0.05)
#
# Proposed Model Precision:
#   Data: [97.0, 86.0, 89.0, 89.0, 76.0, 100.0, 82.0, 93.0]
#   Test Statistic: 0.981104
#   P-value: 0.968162
#   Status: ✓ NORMAL (α = 0.05)
#
# Conclusion:
#   ✓ Both distributions are NORMAL
#   → Recommended Test: Paired T-Test
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# METRIC: Recall
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#
# Yadav et al. Recall:
#   Data: [82.0, 91.0, 94.0, 68.0, 76.0, 60.0, 82.0, 81.0]
#   Test Statistic: 0.951043
#   P-value: 0.721743
#   Status: ✓ NORMAL (α = 0.05)
#
# Proposed Model Recall:
#   Data: [88.0, 98.0, 97.0, 75.0, 91.0, 80.0, 82.0, 87.0]
#   Test Statistic: 0.961357
#   P-value: 0.822927
#   Status: ✓ NORMAL (α = 0.05)
#
# Conclusion:
#   ✓ Both distributions are NORMAL
#   → Recommended Test: Paired T-Test
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# METRIC: F1-Score
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#
# Yadav et al. F1-Score:
#   Data: [86.0, 82.0, 89.0, 75.0, 82.0, 60.0, 79.0, 81.0]
#   Test Statistic: 0.852789
#   P-value: 0.101658
#   Status: ✓ NORMAL (α = 0.05)
#
# Proposed Model F1-Score:
#   Data: [93.0, 91.0, 93.0, 81.0, 83.0, 89.0, 82.0, 90.0]
#   Test Statistic: 0.857505
#   P-value: 0.113379
#   Status: ✓ NORMAL (α = 0.05)
#
# Conclusion:
#   ✓ Both distributions are NORMAL
#   → Recommended Test: Paired T-Test
#
# ====================================================================================================
# SUMMARY TABLE
# ====================================================================================================
#
#    Metric  Yadav_Statistic  Yadav_P-Value  Yadav_Normal  Proposed_Statistic  Proposed_P-Value  Proposed_Normal  Both_Normal Recommended_Test
#  Accuracy         0.952732       0.738721          True            0.961554          0.824764             True         True    Paired T-Test
# Precision         0.898184       0.278252          True            0.981104          0.968162             True         True    Paired T-Test
#    Recall         0.951043       0.721743          True            0.961357          0.822927             True         True    Paired T-Test
#  F1-Score         0.852789       0.101658          True            0.857505          0.113379             True         True    Paired T-Test
#
# ====================================================================================================
# OVERALL RECOMMENDATIONS
# ====================================================================================================
#
# Accuracy:
#   Yadav Status:    True (p = 0.738721)
#   Proposed Status: True (p = 0.824764)
#   Test to Use:     Paired T-Test
#
# Precision:
#   Yadav Status:    True (p = 0.278252)
#   Proposed Status: True (p = 0.968162)
#   Test to Use:     Paired T-Test
#
# Recall:
#   Yadav Status:    True (p = 0.721743)
#   Proposed Status: True (p = 0.822927)
#   Test to Use:     Paired T-Test
#
# F1-Score:
#   Yadav Status:    True (p = 0.101658)
#   Proposed Status: True (p = 0.113379)
#   Test to Use:     Paired T-Test
#
# ====================================================================================================

# %%
from scipy import stats
import numpy as np
import pandas as pd

# Your model results
emotions = ['Anger', 'Calm', 'Disgust', 'Fear', 'Happiness', 'Neutral', 'Sadness', 'Surprise']

yadav_data = {
    'Accuracy': [82.35, 90.91, 93.55, 68.29, 75.76, 60.00, 81.58, 80.95],
    'Precision': [90.00, 74.00, 85.00, 82.00, 89.00, 60.00, 78.00, 81.00],
    'Recall': [82.00, 91.00, 94.00, 68.00, 76.00, 60.00, 82.00, 81.00],
    'F1-Score': [86.00, 82.00, 89.00, 75.00, 82.00, 60.00, 79.00, 81.00],
}

# Proposed model data (EmotionCRNN - based on actual results: Overall Accuracy 88%)
proposed_data = {
    'Accuracy': [88.10, 97.73, 96.88, 75.00, 91.18, 80.00, 82.05, 86.67],
    'Precision': [97.00, 86.00, 89.00, 89.00, 76.00, 100.00, 82.00, 93.00],
    'Recall': [88.00, 98.00, 97.00, 75.00, 91.00, 80.00, 82.00, 87.00],
    'F1-Score': [93.00, 91.00, 93.00, 81.00, 83.00, 89.00, 82.00, 90.00],
}

metrics = ['Accuracy','Precision', 'Recall', 'F1-Score']
alpha = 0.05

# Store results
statistical_results = []

print("\n" + "="*120)
print("PAIRED T-TEST: COMPARING YADAV ET AL. vs PROPOSED MODEL (Overall Performance)")
print("="*120)

for metric in metrics:
    print(f"\n{'─'*120}")
    print(f"METRIC: {metric}")
    print(f"{'─'*120}")
    
    yadav = np.array(yadav_data[metric])
    proposed = np.array(proposed_data[metric])
    differences = proposed - yadav
    
    # Calculate descriptive statistics
    yadav_mean = np.mean(yadav)
    proposed_mean = np.mean(proposed)
    mean_diff = np.mean(differences)
    std_diff = np.std(differences, ddof=1)
    se_diff = std_diff / np.sqrt(len(differences))
    
    print(f"\nYadav et al. {metric}:")
    print(f"  Mean: {yadav_mean:.2f}%")
    print(f"  Std Dev: {np.std(yadav, ddof=1):.2f}%")
    print(f"  Per-emotion values: {yadav.tolist()}")
    
    print(f"\nProposed Model {metric}:")
    print(f"  Mean: {proposed_mean:.2f}%")
    print(f"  Std Dev: {np.std(proposed, ddof=1):.2f}%")
    print(f"  Per-emotion values: {proposed.tolist()}")
    
    print(f"\nPaired Differences (Proposed - Yadav):")
    print(f"  Mean Difference: {mean_diff:.2f}%")
    print(f"  Std Dev of Differences: {std_diff:.2f}%")
    print(f"  Standard Error: {se_diff:.4f}")
    
    # ======================== PAIRED T-TEST ========================
    print(f"\n{'TEST APPLIED':^120}")
    print(f"{'Paired T-Test (Comparing Overall Performance)':^120}")
    print("─"*120)
    
    # Perform paired t-test
    t_statistic, p_value = stats.ttest_rel(proposed, yadav)
    
    # Calculate 95% confidence interval
    df = len(differences) - 1
    t_critical = stats.t.ppf(1 - alpha/2, df)
    ci_lower = mean_diff - t_critical * se_diff
    ci_upper = mean_diff + t_critical * se_diff
    
    # Cohen's d (effect size)
    cohens_d = mean_diff / std_diff if std_diff != 0 else 0
    
    print(f"\nPaired T-Test Results:")
    print(f"  T-Statistic: {t_statistic:.6f}")
    print(f"  P-Value (two-tailed): {p_value:.6f}")
    print(f"  Degrees of Freedom: {df}")
    print(f"  95% Confidence Interval: [{ci_lower:.2f}%, {ci_upper:.2f}%]")
    print(f"  Cohen's d (Effect Size): {cohens_d:.4f}")
    
    # Interpret effect size
    if abs(cohens_d) < 0.2:
        effect_interpretation = "Negligible"
    elif abs(cohens_d) < 0.5:
        effect_interpretation = "Small"
    elif abs(cohens_d) < 0.8:
        effect_interpretation = "Medium"
    else:
        effect_interpretation = "Large"
    
    is_significant = p_value < alpha
    
    print(f"\nConclusion:")
    if is_significant:
        print(f"  ✓ SIGNIFICANT DIFFERENCE (p = {p_value:.6f} < {alpha})")
        if mean_diff > 0:
            print(f"  → Proposed Model performs SIGNIFICANTLY BETTER than Yadav et al.")
        else:
            print(f"  → Yadav et al. performs SIGNIFICANTLY BETTER than Proposed Model")
    else:
        print(f"  ✗ NO SIGNIFICANT DIFFERENCE (p = {p_value:.6f} ≥ {alpha})")
        print(f"  → No statistically significant difference between models")
    
    print(f"  Effect Size: {effect_interpretation} (Cohen's d = {cohens_d:.4f})")
    
    # Store results
    statistical_results.append({
        'Metric': metric,
        'Yadav_Mean': yadav_mean,
        'Proposed_Mean': proposed_mean,
        'Mean_Difference': mean_diff,
        'T_Statistic': t_statistic,
        'P_Value': p_value,
        'CI_Lower': ci_lower,
        'CI_Upper': ci_upper,
        'Cohens_d': cohens_d,
        'Significant': is_significant,
        'Effect_Size': effect_interpretation
    })

# ======================== SUMMARY TABLE ========================
print(f"\n{'='*120}")
print("COMPREHENSIVE SUMMARY TABLE")
print(f"{'='*120}\n")

df_results = pd.DataFrame(statistical_results)
print(df_results.to_string(index=False))

# ======================== OVERALL CONCLUSIONS ========================
print(f"\n{'='*120}")
print("OVERALL CONCLUSIONS")
print(f"{'='*120}")

significant_metrics = [row['Metric'] for row in statistical_results if row['Significant']]
if significant_metrics:
    print(f"\n✓ SIGNIFICANT IMPROVEMENTS in: {', '.join(significant_metrics)}")
else:
    print(f"\n✗ NO SIGNIFICANT IMPROVEMENTS found in any metric")

print(f"\nDetailed Performance Comparison:")
for _, row in df_results.iterrows():
    direction = "↑" if row['Mean_Difference'] > 0 else "↓"
    sig_marker = "***" if row['Significant'] else "ns"
    print(f"  {row['Metric']:12s}: {row['Yadav_Mean']:6.2f}% → {row['Proposed_Mean']:6.2f}% ({direction} {abs(row['Mean_Difference']):5.2f}%, p={row['P_Value']:.4f}) [{sig_marker}]")
# Out:
# ========================================================================================================================
# PAIRED T-TEST: COMPARING YADAV ET AL. vs PROPOSED MODEL (Overall Performance)
# ========================================================================================================================
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# METRIC: Accuracy
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
# Yadav et al. Accuracy:
#   Mean: 79.17%
#   Std Dev: 11.09%
#   Per-emotion values: [82.35, 90.91, 93.55, 68.29, 75.76, 60.0, 81.58, 80.95]
#
# Proposed Model Accuracy:
#   Mean: 87.20%
#   Std Dev: 8.01%
#   Per-emotion values: [88.1, 97.73, 96.88, 75.0, 91.18, 80.0, 82.05, 86.67]
#
# Paired Differences (Proposed - Yadav):
#   Mean Difference: 8.03%
#   Std Dev of Differences: 6.45%
#   Standard Error: 2.2791
#
#                                                       TEST APPLIED
#                                      Paired T-Test (Comparing Overall Performance)
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
# Paired T-Test Results:
#   T-Statistic: 3.522242
#   P-Value (two-tailed): 0.009698
#   Degrees of Freedom: 7
#   95% Confidence Interval: [2.64%, 13.42%]
#   Cohen's d (Effect Size): 1.2453
#
# Conclusion:
#   ✓ SIGNIFICANT DIFFERENCE (p = 0.009698 < 0.05)
#   → Proposed Model performs SIGNIFICANTLY BETTER than Yadav et al.
#   Effect Size: Large (Cohen's d = 1.2453)
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# METRIC: Precision
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
# Yadav et al. Precision:
#   Mean: 79.88%
#   Std Dev: 9.64%
#   Per-emotion values: [90.0, 74.0, 85.0, 82.0, 89.0, 60.0, 78.0, 81.0]
#
# Proposed Model Precision:
#   Mean: 89.00%
#   Std Dev: 7.82%
#   Per-emotion values: [97.0, 86.0, 89.0, 89.0, 76.0, 100.0, 82.0, 93.0]
#
# Paired Differences (Proposed - Yadav):
#   Mean Difference: 9.12%
#   Std Dev of Differences: 14.74%
#   Standard Error: 5.2114
#
#                                                       TEST APPLIED
#                                      Paired T-Test (Comparing Overall Performance)
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
# Paired T-Test Results:
#   T-Statistic: 1.750976
#   P-Value (two-tailed): 0.123417
#   Degrees of Freedom: 7
#   95% Confidence Interval: [-3.20%, 21.45%]
#   Cohen's d (Effect Size): 0.6191
#
# Conclusion:
#   ✗ NO SIGNIFICANT DIFFERENCE (p = 0.123417 ≥ 0.05)
#   → No statistically significant difference between models
#   Effect Size: Medium (Cohen's d = 0.6191)
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# METRIC: Recall
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
# Yadav et al. Recall:
#   Mean: 79.25%
#   Std Dev: 11.22%
#   Per-emotion values: [82.0, 91.0, 94.0, 68.0, 76.0, 60.0, 82.0, 81.0]
#
# Proposed Model Recall:
#   Mean: 87.25%
#   Std Dev: 8.07%
#   Per-emotion values: [88.0, 98.0, 97.0, 75.0, 91.0, 80.0, 82.0, 87.0]
#
# Paired Differences (Proposed - Yadav):
#   Mean Difference: 8.00%
#   Std Dev of Differences: 6.46%
#   Standard Error: 2.2835
#
#                                                       TEST APPLIED
#                                      Paired T-Test (Comparing Overall Performance)
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
# Paired T-Test Results:
#   T-Statistic: 3.503423
#   P-Value (two-tailed): 0.009947
#   Degrees of Freedom: 7
#   95% Confidence Interval: [2.60%, 13.40%]
#   Cohen's d (Effect Size): 1.2386
#
# Conclusion:
#   ✓ SIGNIFICANT DIFFERENCE (p = 0.009947 < 0.05)
#   → Proposed Model performs SIGNIFICANTLY BETTER than Yadav et al.
#   Effect Size: Large (Cohen's d = 1.2386)
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# METRIC: F1-Score
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
# Yadav et al. F1-Score:
#   Mean: 79.25%
#   Std Dev: 8.84%
#   Per-emotion values: [86.0, 82.0, 89.0, 75.0, 82.0, 60.0, 79.0, 81.0]
#
# Proposed Model F1-Score:
#   Mean: 87.75%
#   Std Dev: 4.98%
#   Per-emotion values: [93.0, 91.0, 93.0, 81.0, 83.0, 89.0, 82.0, 90.0]
#
# Paired Differences (Proposed - Yadav):
#   Mean Difference: 8.50%
#   Std Dev of Differences: 8.75%
#   Standard Error: 3.0938
#
#                                                       TEST APPLIED
#                                      Paired T-Test (Comparing Overall Performance)
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
# Paired T-Test Results:
#   T-Statistic: 2.747455
#   P-Value (two-tailed): 0.028609
#   Degrees of Freedom: 7
#   95% Confidence Interval: [1.18%, 15.82%]
#   Cohen's d (Effect Size): 0.9714
#
# Conclusion:
#   ✓ SIGNIFICANT DIFFERENCE (p = 0.028609 < 0.05)
#   → Proposed Model performs SIGNIFICANTLY BETTER than Yadav et al.
#   Effect Size: Large (Cohen's d = 0.9714)
#
# ========================================================================================================================
# COMPREHENSIVE SUMMARY TABLE
# ========================================================================================================================
#
#    Metric  Yadav_Mean  Proposed_Mean  Mean_Difference  T_Statistic  P_Value  CI_Lower  CI_Upper  Cohens_d  Significant Effect_Size
#  Accuracy    79.17375       87.20125           8.0275     3.522242 0.009698  2.638313 13.416687  1.245301         True       Large
# Precision    79.87500       89.00000           9.1250     1.750976 0.123417 -3.197956 21.447956  0.619063        False      Medium
#    Recall    79.25000       87.25000           8.0000     3.503423 0.009947  2.600425 13.399575  1.238647         True       Large
#  F1-Score    79.25000       87.75000           8.5000     2.747455 0.028609  1.184390 15.815610  0.971372         True       Large
#
# ========================================================================================================================
# OVERALL CONCLUSIONS
# ========================================================================================================================
#
# ✓ SIGNIFICANT IMPROVEMENTS in: Accuracy, Recall, F1-Score
#
# Detailed Performance Comparison:
#   Accuracy    :  79.17% →  87.20% (↑  8.03%, p=0.0097) [***]
#   Precision   :  79.88% →  89.00% (↑  9.12%, p=0.1234) [ns]
#   Recall      :  79.25% →  87.25% (↑  8.00%, p=0.0099) [***]
#   F1-Score    :  79.25% →  87.75% (↑  8.50%, p=0.0286) [***]
